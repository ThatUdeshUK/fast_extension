# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

# %%
font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
fast = pd.read_csv("../results_remote/FAST_KNN_NO_ObjIndex_L9.csv")
ckqst = pd.read_csv("../results_remote/CKQST_KNN_NO.csv")

fast_lazy = pd.read_csv("../results_remote/FAST_KNN_NO_ObjIndex_L9_lazy.csv")
fast_lazy_est = pd.read_csv("../results_remote/FAST_KNN_NO_ObjIndex_L9_lazy_est.csv")

# fast_L6 = pd.read_csv("../results_remote/FAST_KNN_NO_ObjIndex_L6.csv")
# fast_L3 = pd.read_csv("../results_remote/FAST_KNN_NO_ObjIndex_L3.csv")
# fast_minkeys2 = pd.read_csv("../results_03_15/FAST_KNN_NO_ObjIndex_L9_minkeys2.csv")

# fast_spatialuni = pd.read_csv("../results_03_15/FAST_KNN_NO_ObjIndex_L9_spatialuni.csv")
# ckqst_spatialuni = pd.read_csv("../results_03_15/CKQST_KNN_NO_L9_spatialuni.csv")

res = pd.concat([
    fast.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    ckqst.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    # fast_L6.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    # fast_minkeys2.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    # fast_L3.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    fast_lazy.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    # fast_lazy_est.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],

    # fast_spatialuni.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
    # ckqst_spatialuni.loc[:, ['creation_time', 'search_time', 'num_queries', 'name']],
])

# res.loc[res["name"] == "FAST_KNN_NO_ObjIndex_objFreq", "creation_time"] = 1

name_map = {
    "FAST_KNN_NO_ObjIndex_L9": "FAST - Strat. 5",
    "FAST_KNN_NO_ObjIndex_L6": "FAST - Strat. 5 (maxLevel=6)",
    "FAST_KNN_NO_ObjIndex_L3": "FAST - Strat. 5 (maxLevel=3)",
    "FAST_KNN_NO_ObjIndex_L9_minkeys2": "FAST - Strat. 5 (maxLevel=9, minkeys=2)",
    "FAST_KNN_NO_ObjIndex_L9_lazy": "FAST - Strat. 5 (lazy )",
    "FAST_KNN_NO_ObjIndex_L9_lazy_est": "FAST - Strat. 5 (lazy one-per-trie)",

    # "FAST_KNN_NO_ObjIndex_L9_spatialuni": "FAST - Strat. 5 (SpatialUni)",
    "CkQST_KNN_NO": "CkQST (Baseline)",
    # "CkQST_KNN_NO_L9_spatialuni": "CkQST (SpatialUni)",
}
res['name'] = res['name'].apply(lambda x: name_map[x])
res = res.sort_values(by=['name'])
# res = res[~(res['num_queries'] == 100000)]
res
# Out:
#     creation_time   search_time  num_queries  \
# 5   4620151710187   82997306651      5000000
# 11  4417037671979  111818209963      5000000
# 10  1924821451309   29437459056      2500000
# 9   1397974393762   26183910526      2000000
# 8    494819758329   12265518064      1000000
# 7    240069769365    5914458616       500000
# 6     47584699853    1771678913       100000
# 4   1947331720885   35311856108      2500000
# 3   1610701124868   32902856268      2000000
# 2    513526573478   12681489298      1000000
# 1    255807353246    6162615437       500000
# 0     47890667445    2062519821       100000
# 0     46506970112    3713270901       100000
# 10  1883972720252   25010461436      2500000
# 11  4523589255345   35929140281      5000000
# 2    478096256662   18899236893      1000000
# 3   1394393340948   23793069006      2000000
# 4   2005174396716   23692442136      2500000
# 5   4542912275730   33955962355      5000000
# 1    236087843997   11745580648       500000
# 7    229735386121   13493236637       500000
# 8    474408799047   17715231395      1000000
# 9   1352750807148   24216121260      2000000
# 6     45559589840    3772850386       100000
# 0     17071923177    6206195019       100000
# 1    120206637366   18032256744       500000
# 2    277020242325   23049964236      1000000
# 3     16083055209    6120588368       100000
# 4    116519699907   18498165594       500000
# 5    306021985687   24464978074      1000000
# 6    794766440680   27475273655      2000000
# 7   1256068660113   29834676652      2500000
# 8   3302712010013   44709654199      5000000
# 0     45242419933   13672951242       100000
# 1   1322126471909   68636767739       500000
#
#                                    name
# 5                      CkQST (Baseline)
# 11                     CkQST (Baseline)
# 10                     CkQST (Baseline)
# 9                      CkQST (Baseline)
# 8                      CkQST (Baseline)
# 7                      CkQST (Baseline)
# 6                      CkQST (Baseline)
# 4                      CkQST (Baseline)
# 3                      CkQST (Baseline)
# 2                      CkQST (Baseline)
# 1                      CkQST (Baseline)
# 0                      CkQST (Baseline)
# 0                       FAST - Strat. 5
# 10                      FAST - Strat. 5
# 11                      FAST - Strat. 5
# 2                       FAST - Strat. 5
# 3                       FAST - Strat. 5
# 4                       FAST - Strat. 5
# 5                       FAST - Strat. 5
# 1                       FAST - Strat. 5
# 7                       FAST - Strat. 5
# 8                       FAST - Strat. 5
# 9                       FAST - Strat. 5
# 6                       FAST - Strat. 5
# 0               FAST - Strat. 5 (lazy )
# 1               FAST - Strat. 5 (lazy )
# 2               FAST - Strat. 5 (lazy )
# 3               FAST - Strat. 5 (lazy )
# 4               FAST - Strat. 5 (lazy )
# 5               FAST - Strat. 5 (lazy )
# 6               FAST - Strat. 5 (lazy )
# 7               FAST - Strat. 5 (lazy )
# 8               FAST - Strat. 5 (lazy )
# 0   FAST - Strat. 5 (lazy one-per-trie)
# 1   FAST - Strat. 5 (lazy one-per-trie)

# %%
search_res = res.loc[:, ['creation_time', 'num_queries', 'name']]
search_res = search_res[search_res['num_queries'] > 10000]
search_res['Index creation time (sec)'] = search_res['creation_time'].apply(lambda x: x) / 1000000000
search_res = search_res.rename(columns={"num_queries": "No. of queries"})

ax = sns.lineplot(x="No. of queries", y='Index creation time (sec)', hue='name', style='name', data=search_res, errorbar='sd',
             markers=True)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1))
# Out:
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
test = pd.DataFrame(res[res['num_queries'] == 500000])
test['search_time'] = test['search_time'].apply(lambda x: x / 500000)
test
# Out:
#    creation_time    search_time  num_queries  \
# 7   240069769365   11828.917232       500000
# 1   255807353246   12325.230874       500000
# 1   236087843997   23491.161296       500000
# 7   229735386121   26986.473274       500000
# 1   120206637366   36064.513488       500000
# 4   116519699907   36996.331188       500000
# 1  1322126471909  137273.535478       500000
#
#                                   name
# 7                     CkQST (Baseline)
# 1                     CkQST (Baseline)
# 1                      FAST - Strat. 5
# 7                      FAST - Strat. 5
# 1              FAST - Strat. 5 (lazy )
# 4              FAST - Strat. 5 (lazy )
# 1  FAST - Strat. 5 (lazy one-per-trie)

# %%
res[res['num_queries'] == 2500000]
# Out:
#     creation_time  search_time  num_queries                     name
# 10  1924821451309  29437459056      2500000         CkQST (Baseline)
# 4   1947331720885  35311856108      2500000         CkQST (Baseline)
# 10  1883972720252  25010461436      2500000          FAST - Strat. 5
# 4   2005174396716  23692442136      2500000          FAST - Strat. 5
# 7   1256068660113  29834676652      2500000  FAST - Strat. 5 (lazy )

# %%
search_res = res.loc[:, ['search_time', 'num_queries', 'name']]
search_res['Query Matching Time (ms)'] = search_res['search_time'].apply(lambda x: x) / (
            search_res['num_queries'] * 1000000)
search_res = search_res.rename(columns={"num_queries": "No. of queries"})
# create_res['experiment'] = create_res['name'].apply(expName)

ax = sns.lineplot(x="No. of queries", y='Query Matching Time (ms)', hue='name', style='name', data=search_res, errorbar='sd', markers=True)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1))
# Out:
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Optimization
# - Custom iterator
# - Circle bound calculation
