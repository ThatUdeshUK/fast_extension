# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
create_time = pd.read_csv("../results_03_15/CKQST_KNN_NO_L9_search_sub_timeline_2500000_100000.csv", names=['obj_search', 'insert', 'ar', 'des_count', 'level']).reset_index()
create_time['name'] = 'ckqst'
create_time['obj_search'] = create_time['obj_search'] / 1000000
create_time['insert'] = create_time['insert'] * 4 / 1000000
create_time = create_time.melt(id_vars=['index', 'name', 'ar', 'des_count', 'level'], var_name='stage', value_name='time')
create_time['time'] = create_time['time'].apply(lambda x: 200 if x > 200 else x)
create_time
# Out:
#            index   name          ar  des_count  level       stage       time
# 0              0  ckqst    2.646341          0      0  obj_search  10.604716
# 1              1  ckqst   17.806978          0      0  obj_search  10.480933
# 2              2  ckqst  113.705647          0      0  obj_search   0.203384
# 3              3  ckqst    9.208080          0      0  obj_search   0.110885
# 4              4  ckqst    1.264358          0      0  obj_search   0.360263
# ...          ...    ...         ...        ...    ...         ...        ...
# 4999995  2499995  ckqst    0.243780          0      0      insert   0.003736
# 4999996  2499996  ckqst    3.895217          0      0      insert   0.009612
# 4999997  2499997  ckqst    8.129695          0      0      insert   0.020684
# 4999998  2499998  ckqst   70.579975          0      0      insert   0.010134
# 4999999  2499999  ckqst    1.070561          0      0      insert   0.012080
#
# [5000000 rows x 7 columns]

# %% [markdown]
# ## Creation time

# %%
plt.figure(figsize=(16,3))
sns.histplot(x='time', bins=500, hue='stage', multiple='layer', data=create_time)
plt.xlabel('time (milis)')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# **Miserable queries**
#
# Queries that takes too much time (>100 milis).

# %%
miserable_queries = create_time[create_time['time'] > 5].sort_values('time', ascending=False)
miserable_queries
# Out:
#            index   name             ar  des_count  level       stage  \
# 1352968  1352968  ckqst  1.797693e+308          0      0  obj_search
# 527563    527563  ckqst  1.797693e+308          0      0  obj_search
# 1921923  1921923  ckqst  1.797693e+308          0      0  obj_search
# 1979172  1979172  ckqst   1.808205e+02          0      0  obj_search
# 898318    898318  ckqst  1.797693e+308          0      0  obj_search
# ...          ...    ...            ...        ...    ...         ...
# 1128680  1128680  ckqst  1.797693e+308          0      0  obj_search
# 2391415  2391415  ckqst  1.797693e+308          0      0  obj_search
# 585073    585073  ckqst  1.797693e+308          0      0  obj_search
# 2198318  2198318  ckqst  1.797693e+308          0      0  obj_search
# 1580831  1580831  ckqst   2.005425e+02          0      0  obj_search
#
#                time
# 1352968  200.000000
# 527563   140.273136
# 1921923  135.092543
# 1979172  129.945396
# 898318   122.708434
# ...             ...
# 1128680    5.000126
# 2391415    5.000105
# 585073     5.000018
# 2198318    5.000011
# 1580831    5.000009
#
# [70781 rows x 7 columns]

# %%
# step = 500000
# for i in range(0, 2500000, step):
plt.figure(figsize=(16,3))
sns.lineplot(x='index', y='time', hue='stage', style='stage', data=create_time)
plt.xlabel('timestamp')
plt.ylabel('time (milis)')
# Out:
# Text(0, 0.5, 'time (milis)')

# %% [markdown]
# Relative time (FAST vs CkQST)

# %%
# relative_create = create_time[create_time['stage'] == 'insert']['time'].reset_index() - create_time[create_time['stage'] == 'obj_search']['time'].reset_index()
# relative_create
# plt.figure(figsize=(16,8))
# sns.lineplot(data=relative_create)
# plt.xlabel('timestamp')
# plt.ylabel('time (milis)')

# %% [markdown]
# ## Load Queries

# %%
queries_df = pd.read_json('../../data/exported/places_o200000_q2500000_scaled.json', lines=True);
queries_df = queries_df.iloc[200000:, :].reset_index(drop=True).drop(columns=['id']).reset_index()

queries_df.tail()
# Out:
#            index           x           y  \
# 2499995  2499995  409.894898  103.097463
# 2499996  2499996  402.284307  107.998284
# 2499997  2499997  406.953882  110.040834
# 2499998  2499998  412.621720  107.253521
# 2499999  2499999  412.835319  107.262331
#
#                                              keywords  scaled
# 2499995                         [telephone, cellular]    True
# 2499996                                  [contractor]    True
# 2499997                                      [church]    True
# 2499998          [lounge, drinking, eating, cocktail]    True
# 2499999  [coping, plastering, tiling, pool, swimming]    True

# %% [markdown]
# ### Properties of miserable queries

# %%
queries_df.shape
# Out:
# (2500000, 5)

# %%
details = queries_df.join(miserable_queries.set_index('index'), on='index').dropna().sort_values('time', ascending=False)
# details = details[details['name'] == 'fast']
details['ar'] = details['ar'].apply(lambda x: np.inf if x > 512 else x)
all = details.drop(columns=['x', 'y']).rename(columns={'time': 'insertion time (milis)'})

# %%
obj_search = all[all['stage'] == 'obj_search']
insert = all[all['stage'] == 'insert']

# insert#.join(ckqsts, rsuffix='_')
insert.head(25)
# Out:
#            index                 keywords  scaled   name         ar  \
# 1545775  1545775               [investor]    True  ckqst   0.949405
# 1993496  1993496                    [saw]    True  ckqst   4.789314
# 325822    325822  [educational, software]    True  ckqst   2.197808
# 919545    919545             [cargo, air]    True  ckqst   6.958532
# 1618828  1618828              [financing]    True  ckqst        inf
# 1307346  1307346    [hanging, contractor]    True  ckqst   7.757309
# 1959334  1959334              [fraternal]    True  ckqst  16.354238
# 920541    920541   [operated, phonograph]    True  ckqst   5.018370
# 1200497  1200497            [car, dealer]    True  ckqst   4.839111
# 922917    922917             [consultant]    True  ckqst   3.151083
# 1853510  1853510     [paint, ball, sport]    True  ckqst   3.306876
# 1685756  1685756                 [eating]    True  ckqst  32.407016
#
#          des_count  level   stage  insertion time (milis)
# 1545775        0.0    0.0  insert              104.265250
# 1993496        0.0    0.0  insert              100.796330
# 325822         0.0    0.0  insert               74.435176
# 919545         0.0    0.0  insert               57.040486
# 1618828        0.0    0.0  insert               19.554020
# 1307346        0.0    0.0  insert               11.964054
# 1959334        0.0    0.0  insert                9.196568
# 920541         0.0    0.0  insert                6.096470
# 1200497        0.0    0.0  insert                5.327318
# 922917         0.0    0.0  insert                5.266592
# 1853510        0.0    0.0  insert                5.202732
# 1685756        0.0    0.0  insert                5.040338

# %%
obj_search.head(25)
# Out:
#            index                                           keywords  scaled  \
# 1352968  1352968                                         [software]    True
# 527563    527563                             [consultant, business]    True
# 1921923  1921923                              [commercial, storage]    True
# 1979172  1979172                                          [village]    True
# 898318    898318  [organization, parts, electronic, cooperative,...    True
# 454836    454836                                     [distribution]    True
# 922917    922917                                       [consultant]    True
# 2021889  2021889                                [cosmetic, perfume]    True
# 1307328  1307328                              [swimwear, accessory]    True
# 1366444  1366444                                       [inspection]    True
# 225680    225680                           [electrical, contractor]    True
# 1147537  1147537                                          [printer]    True
# 2417089  2417089                                    [grain, broker]    True
# 1600445  1600445                      [equipment, electric, supply]    True
# 528372    528372                               [home, convalescent]    True
# 1504575  1504575                                           [eating]    True
# 2021691  2021691                                          [medical]    True
# 2150366  2150366                                    [crop, general]    True
# 2092928  2092928                                             [shop]    True
# 461893    461893                                [graphic, designer]    True
# 936901    936901                               [physician, surgeon]    True
# 1028210  1028210                     [professional, baseball, team]    True
# 2121421  2121421                                        [reporting]    True
# 2036020  2036020                                [station, gasoline]    True
# 1807986  1807986               [equipment, aircraft, parts, supply]    True
#
#           name          ar  des_count  level       stage  \
# 1352968  ckqst         inf        0.0    0.0  obj_search
# 527563   ckqst         inf        0.0    0.0  obj_search
# 1921923  ckqst         inf        0.0    0.0  obj_search
# 1979172  ckqst  180.820514        0.0    0.0  obj_search
# 898318   ckqst         inf        0.0    0.0  obj_search
# 454836   ckqst         inf        0.0    0.0  obj_search
# 922917   ckqst    3.151083        0.0    0.0  obj_search
# 2021889  ckqst         inf        0.0    0.0  obj_search
# 1307328  ckqst         inf        0.0    0.0  obj_search
# 1366444  ckqst         inf        0.0    0.0  obj_search
# 225680   ckqst   54.541774        0.0    0.0  obj_search
# 1147537  ckqst  176.581469        0.0    0.0  obj_search
# 2417089  ckqst         inf        0.0    0.0  obj_search
# 1600445  ckqst         inf        0.0    0.0  obj_search
# 528372   ckqst    8.204862        0.0    0.0  obj_search
# 1504575  ckqst    2.083666        0.0    0.0  obj_search
# 2021691  ckqst         inf        0.0    0.0  obj_search
# 2150366  ckqst         inf        0.0    0.0  obj_search
# 2092928  ckqst   95.421062        0.0    0.0  obj_search
# 461893   ckqst         inf        0.0    0.0  obj_search
# 936901   ckqst         inf        0.0    0.0  obj_search
# 1028210  ckqst         inf        0.0    0.0  obj_search
# 2121421  ckqst         inf        0.0    0.0  obj_search
# 2036020  ckqst         inf        0.0    0.0  obj_search
# 1807986  ckqst         inf        0.0    0.0  obj_search
#
#          insertion time (milis)
# 1352968              200.000000
# 527563               140.273136
# 1921923              135.092543
# 1979172              129.945396
# 898318               122.708434
# 454836               104.761420
# 922917               103.442939
# 2021889               93.565346
# 1307328               90.859548
# 1366444               89.674409
# 225680                89.670328
# 1147537               77.738006
# 2417089               76.184311
# 1600445               75.311824
# 528372                73.385111
# 1504575               73.243672
# 2021691               72.321532
# 2150366               71.774139
# 2092928               71.216839
# 461893                71.192004
# 936901                70.514909
# 1028210               69.184085
# 2121421               68.438617
# 2036020               68.032098
# 1807986               67.983644

# %% [markdown]
# ### Extract Inf

# %%
inf_queries = obj_search[obj_search['ar'] == np.inf]

# %%
# inf_queries['index'].to_csv('../../data/exported/places_o200000_q2500000_scaled.inf.csv')
