# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
fast = pd.read_csv("../results/FAST_KNN_NO_MEM.csv")
fast['name'] = "Strat 3. - FAST (AR thres: 25.0)"

fast_obj = pd.read_csv("../results/FAST_KNN_NO_ObjIndex_MEM.csv")
fast_obj['name'] = "Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index"

fast_ar = pd.read_csv("../results/FAST_KNN_NO_MEM2.csv")
fast_ar['name'] = "Strat 3. - FAST (AR thres: 5.0)"

fast_ar_obj = pd.read_csv("../results/FAST_KNN_NO_ObjIndex_MEM3.csv")
fast_ar_obj['name'] = "Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index"


ckqst = pd.read_csv("../results/CkQST_KNN_NO_MEM.csv")
ckqst['name'] = "CkQST (baseline)"

res = pd.concat([
    fast.loc[:, ['create_mem', 'search_mem', 'num_queries', 'name']],
    fast_obj.loc[:, ['create_mem', 'search_mem', 'num_queries', 'name']],
    fast_ar.loc[:, ['create_mem', 'search_mem', 'num_queries', 'name']],
    fast_ar_obj.loc[:, ['create_mem', 'search_mem', 'num_queries', 'name']],
    ckqst.loc[:, ['create_mem', 'search_mem', 'num_queries', 'name']]
]).rename(columns={'create_mem': "After creation", 'search_mem': "After search"})

res
# Out:
#    After creation  After search  num_queries  \
# 0        39074408      95348208       100000
# 1       192551640     717180944       500000
# 2       384394208    1759936320      1000000
# 3       766913624    3855648136      2000000
# 4       955351360    5277818496      2500000
# 0       104603928     164364696       100000
# 1       255766800     352555976       500000
# 2       444842720     584989232      1000000
# 0        39074408      75062960       100000
# 1       192551640     276696000       500000
# 2       384394208     541566456      1000000
# 3       766913624    1063528784      2000000
# 4       955351360    1317612848      2500000
# 0       104603928     164364696       100000
# 1       255766800     352555976       500000
# 2       444842720     584989232      1000000
# 0       108924392     175498000       100000
# 1       239007272     370214544       500000
# 2       390923472     599800112      1000000
#
#                                              name
# 0                Strat 3. - FAST (AR thres: 25.0)
# 1                Strat 3. - FAST (AR thres: 25.0)
# 2                Strat 3. - FAST (AR thres: 25.0)
# 3                Strat 3. - FAST (AR thres: 25.0)
# 4                Strat 3. - FAST (AR thres: 25.0)
# 0  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index
# 1  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index
# 2  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index
# 0                 Strat 3. - FAST (AR thres: 5.0)
# 1                 Strat 3. - FAST (AR thres: 5.0)
# 2                 Strat 3. - FAST (AR thres: 5.0)
# 3                 Strat 3. - FAST (AR thres: 5.0)
# 4                 Strat 3. - FAST (AR thres: 5.0)
# 0   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index
# 1   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index
# 2   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index
# 0                                CkQST (baseline)
# 1                                CkQST (baseline)
# 2                                CkQST (baseline)

# %%
out = res.melt(id_vars=["name", 'num_queries'], var_name="State")
out['value'] = out['value'] / 1048576
# out = out[out['num_queries'] < 2000000]
out.set_index(["name", "num_queries", "State"], inplace=True)
# out["vcs"] = out.groupby(level=["name", "num_queries"]).cumsum()
out.reset_index(inplace=True) 
# out = out.rename(columns={"num_queries": "No. of queries", 'value': "Index size (MB)"})

for i, g in enumerate(out.groupby("State")):
    ax = sns.barplot(data=g[1],
                     x="num_queries",
                     y="value",
                     hue="name",
                     # color=c[i],
                     zorder=-i, # so first bars stay on top
                     edgecolor="k")
    if i == 0:
        for bar in ax.patches:
            bar.set_hatch('//')

plt.ylabel('Index size (MB)')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1))

# for i, g in enumerate(dfall.groupby("variable")):
#     plt.figure()
#     sns.lineplot(x="No. of queries", y='Index size (MB)', style='name', data=out[out['State'] == state], errorbar=None, markers=True)
#     plt.show()
    # ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1))

# %%
out
# Out:
#                                               name  num_queries  \
# 0                 Strat 3. - FAST (AR thres: 25.0)       100000
# 1                 Strat 3. - FAST (AR thres: 25.0)       500000
# 2                 Strat 3. - FAST (AR thres: 25.0)      1000000
# 3   Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index       100000
# 4   Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index       500000
# 5   Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index      1000000
# 6                  Strat 3. - FAST (AR thres: 5.0)       100000
# 7                  Strat 3. - FAST (AR thres: 5.0)       500000
# 8                  Strat 3. - FAST (AR thres: 5.0)      1000000
# 9    Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index       100000
# 10   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index       500000
# 11   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index      1000000
# 12                                CkQST (baseline)       100000
# 13                                CkQST (baseline)       500000
# 14                                CkQST (baseline)      1000000
# 15                Strat 3. - FAST (AR thres: 25.0)       100000
# 16                Strat 3. - FAST (AR thres: 25.0)       500000
# 17                Strat 3. - FAST (AR thres: 25.0)      1000000
# 18  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index       100000
# 19  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index       500000
# 20  Strat 4. - FAST (AR thres: 25.0) w/ Obj. Index      1000000
# 21                 Strat 3. - FAST (AR thres: 5.0)       100000
# 22                 Strat 3. - FAST (AR thres: 5.0)       500000
# 23                 Strat 3. - FAST (AR thres: 5.0)      1000000
# 24   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index       100000
# 25   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index       500000
# 26   Strat 4. - FAST (AR thres: 5.0) w/ Obj. Index      1000000
# 27                                CkQST (baseline)       100000
# 28                                CkQST (baseline)       500000
# 29                                CkQST (baseline)      1000000
#
#              State        value
# 0   After creation    37.264259
# 1   After creation   183.631554
# 2   After creation   366.586884
# 3   After creation    99.758080
# 4   After creation   243.918228
# 5   After creation   424.235077
# 6   After creation    37.264259
# 7   After creation   183.631554
# 8   After creation   366.586884
# 9   After creation    99.758080
# 10  After creation   243.918228
# 11  After creation   424.235077
# 12  After creation   103.878395
# 13  After creation   227.935097
# 14  After creation   372.813675
# 15    After search    90.931137
# 16    After search   683.957047
# 17    After search  1678.406067
# 18    After search   156.750389
# 19    After search   336.223579
# 20    After search   557.889206
# 21    After search    71.585617
# 22    After search   263.877869
# 23    After search   516.478020
# 24    After search   156.750389
# 25    After search   336.223579
# 26    After search   557.889206
# 27    After search   167.367935
# 28    After search   353.064102
# 29    After search   572.013962

# %%
dfall.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dfall.reset_index(inplace=True)
#
# NameError: name 'dfall' is not defined
