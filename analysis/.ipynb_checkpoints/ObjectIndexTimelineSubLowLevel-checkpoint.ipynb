# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
create_time = pd.read_csv("../results_03_01/FAST_KNN_NO_ObjIndex_noInf_search_sub_timeline_2500000_100000.csv", names=['obj_search', 'insert']).reset_index()
create_time['name'] = 'fast'
create_time['obj_search'] = create_time['obj_search'] / 1000000
create_time['insert'] = create_time['insert'] / 1000000
create_time = create_time.melt(id_vars=['index', 'name'], var_name='stage', value_name='time')

create_time
# Out:
#            index  name       stage      time
# 0              0  fast  obj_search  9.164311
# 1              1  fast  obj_search  8.873392
# 2              2  fast  obj_search  0.279477
# 3              3  fast  obj_search  0.338487
# 4              4  fast  obj_search  0.626474
# ...          ...   ...         ...       ...
# 4999995  2499995  fast      insert  0.000999
# 4999996  2499996  fast      insert  0.000935
# 4999997  2499997  fast      insert  0.003054
# 4999998  2499998  fast      insert  0.001703
# 4999999  2499999  fast      insert  0.001880
#
# [5000000 rows x 4 columns]

# %% [markdown]
# ## Creation time

# %%
plt.figure(figsize=(16,3))
sns.histplot(x='time', bins=500, hue='stage', multiple='layer', data=create_time)
plt.xlabel('time (milis)')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# **Miserable queries**
#
# Queries that takes too much time (>100 milis).

# %%
miserable_queries = create_time[create_time['time'] > 50].sort_values('time', ascending=False)
miserable_queries
# Out:
#            index  name       stage        time
# 96219      96219  fast  obj_search  131.400025
# 2078046  2078046  fast  obj_search  124.890448
# 2304347  2304347  fast  obj_search  119.089713
# 247646    247646  fast  obj_search   92.933440
# 54820      54820  fast  obj_search   90.172547
# ...          ...   ...         ...         ...
# 528079    528079  fast  obj_search   50.659132
# 1185233  1185233  fast  obj_search   50.564548
# 1715994  1715994  fast  obj_search   50.214537
# 1345758  1345758  fast  obj_search   50.084766
# 1660399  1660399  fast  obj_search   50.057085
#
# [93 rows x 4 columns]

# %%
# step = 500000
# for i in range(0, 2500000, step):
plt.figure(figsize=(16,3))
sns.lineplot(x='index', y='time', hue='stage', style='stage', data=create_time)
plt.xlabel('timestamp')
plt.ylabel('time (milis)')
# Out:
# Text(0, 0.5, 'time (milis)')

# %% [markdown]
# Relative time (FAST vs CkQST)

# %%
# relative_create = create_time[create_time['stage'] == 'insert']['time'].reset_index() - create_time[create_time['stage'] == 'obj_search']['time'].reset_index()
# relative_create
# plt.figure(figsize=(16,8))
# sns.lineplot(data=relative_create)
# plt.xlabel('timestamp')
# plt.ylabel('time (milis)')

# %% [markdown]
# ## Load Queries

# %%
queries_df = pd.read_csv('../data/Places_Queries_2500000.csv');

queries_df.tail()
# Out:
#               id           x           y             keywords  k         ar  \
# 2499995  2499995  260.643938  110.297883           contractor  5   0.195442
# 2499996  2499996  278.661373  197.628919                 used  5   3.854567
# 2499997  2499997  260.217315   69.398765  carpet|cleaners|rug  5   4.791082
# 2499998  2499998  167.413845  140.794951             regional  5  53.612263
# 2499999  2499999  256.967070   86.626912               church  5   0.874051
#
#          current_level       st       et
# 2499995              9  2499995  2800001
# 2499996              9  2499996  2800001
# 2499997              9  2499997  2800001
# 2499998              9  2499998  2800001
# 2499999              9  2499999  2800001

# %% [markdown]
# ### Properties of miserable queries

# %%
queries_df.shape
# Out:
# (2500000, 9)

# %%
details = queries_df.join(miserable_queries.set_index('index'), on='id').dropna().sort_values('time', ascending=False)
# details = details[details['name'] == 'fast']
details['ar'] = details['ar'].apply(lambda x: np.inf if x > 512 else x)
all = details.drop(columns=['current_level', 'id', 'k', 'st', 'et']).rename(columns={'time': 'insertion time (milis)'})

# %%
obj_search = all[all['stage'] == 'obj_search']
insert = all[all['stage'] == 'insert']

insert#.join(ckqsts, rsuffix='_')
obj_search.head(25)
# Out:
#                   x           y  \
# 96219    257.945893   80.307599
# 2078046  260.033196  131.093082
# 2304347  261.334938  107.051700
# 247646   239.380235  175.730984
# 54820    136.311052  181.868383
# 312357   138.925149  191.624978
# 2248329  263.721662   88.066588
# 2287275  265.396437   73.834562
# 2428295  264.857914   65.724665
# 344861   147.868118  148.484119
# 2407498  148.736994  144.552094
# 2448009  260.779532  119.396415
# 1276311  265.099869   68.142677
# 2468092  264.419065   66.795083
# 87667    137.606281  173.763622
# 2487729  242.311927  183.613424
# 1566958  241.816818  220.237532
# 1456065  264.392440   64.363486
# 1239374  143.504015  173.319360
# 1979529  245.112814  142.079444
# 611606   285.368845  215.201665
# 2387461  246.686241  202.434463
# 1789729   51.197906  411.349818
# 2094010  245.673080  200.996108
# 220133   264.988234   70.557675
#
#                                                   keywords          ar  name  \
# 96219                 contractor|metalwork|mfg|sheet|trade         inf  fast
# 2078046            contractor|electric|electrical|plumbing         inf  fast
# 2304347                general|merchandise|mfg|preparation         inf  fast
# 247646     architectural|contractor|ironwork|metalwork|mfg         inf  fast
# 54820                devices|medical|mfg|physician|surgeon         inf  fast
# 312357   agency|arrangement|bureau|passenger|transporta...         inf  fast
# 2248329                    concrete|contractor|mfg|product         inf  fast
# 2287275                        co|contractor|general|house         inf  fast
# 2428295      air|conditioning|contractor|mechanical|system         inf  fast
# 344861                                 advertising|product         inf  fast
# 2407498                automotive|industrial|machinery|mfg         inf  fast
# 2448009                            camp|contractor|logging         inf  fast
# 1276311                               dealer|marine|supply         inf  fast
# 2468092                contractor|mechanical|refrigeration         inf  fast
# 87667                                     preparation|soil  101.809786  fast
# 2487729                                    automobile|used   26.337805  fast
# 1566958        carpentry|contractor|general|nonresidential         inf  fast
# 1456065                 contractor|family|general|home|new         inf  fast
# 1239374                                broker|federal|loan         inf  fast
# 1979529                                    care|church|day         inf  fast
# 611606             construction|contractor|general|manager         inf  fast
# 2387461                         mfg|pharmaceutical|product         inf  fast
# 1789729                           contractor|general|heavy         inf  fast
# 2094010                             cooler|equipment|water         inf  fast
# 220133                                  auction|automobile         inf  fast
#
#               stage  insertion time (milis)
# 96219    obj_search              131.400025
# 2078046  obj_search              124.890448
# 2304347  obj_search              119.089713
# 247646   obj_search               92.933440
# 54820    obj_search               90.172547
# 312357   obj_search               78.004746
# 2248329  obj_search               74.882581
# 2287275  obj_search               73.491525
# 2428295  obj_search               69.199028
# 344861   obj_search               68.452693
# 2407498  obj_search               65.957844
# 2448009  obj_search               65.900745
# 1276311  obj_search               65.882683
# 2468092  obj_search               65.458160
# 87667    obj_search               65.165722
# 2487729  obj_search               64.891259
# 1566958  obj_search               64.587788
# 1456065  obj_search               64.391712
# 1239374  obj_search               62.735768
# 1979529  obj_search               62.689784
# 611606   obj_search               62.202755
# 2387461  obj_search               62.003846
# 1789729  obj_search               61.888086
# 2094010  obj_search               61.668729
# 220133   obj_search               61.140525
