# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
create_time = pd.read_csv("../remote_results/FAST_KNN_NO_ObjIndex_L9_lazy_search_sub_timeline_2500000_100000.csv", names=['obj_search', 'insert', 'ar', 'des_count', 'level']).reset_index()
create_time['name'] = 'fast'
create_time['obj_search'] = create_time['obj_search'] / 1000000
create_time['insert'] = create_time['insert'] / 1000000
create_time = create_time.melt(id_vars=['index', 'name', 'ar', 'des_count', 'level'], var_name='stage', value_name='time')

create_time
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 create_time = pd.read_csv("../results_03_15/FAST_KNN_NO_ObjIndex_L9_lazy_search_sub_timeline_2500000_100000.csv", names=['obj_search', 'insert', 'ar', 'des_count', 'level']).reset_index()
#       2 create_time['name'] = 'fast'
#       3 create_time['obj_search'] = create_time['obj_search'] / 1000000
#
# File ~/Library/miniconda3/envs/fast/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/miniconda3/envs/fast/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/Library/miniconda3/envs/fast/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/miniconda3/envs/fast/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/Library/miniconda3/envs/fast/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results_03_15/FAST_KNN_NO_ObjIndex_L9_lazy_search_sub_timeline_2500000_100000.csv'

# %% [markdown]
# ## Creation time

# %%
plt.figure(figsize=(16,3))
sns.histplot(x='time', bins=500, hue='stage', multiple='layer', data=create_time)
plt.xlabel('time (milis)')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# **Miserable queries**
#
# Queries that takes too much time (>100 milis).

# %%
miserable_queries = create_time[create_time['time'] > 5].sort_values('time', ascending=False)
miserable_queries
# Out:
#            index  name             ar  des_count  level       stage  \
# 14819      14819  fast  1.797693e+308          0      9  obj_search
# 203625    203625  fast   8.139169e+01          0      9  obj_search
# 920702    920702  fast  1.797693e+308          0      9  obj_search
# 909570    909570  fast  1.797693e+308          0      9  obj_search
# 56933      56933  fast  1.797693e+308          0      9  obj_search
# ...          ...   ...            ...        ...    ...         ...
# 1637681  1637681  fast  1.797693e+308          0      9  obj_search
# 2015413  2015413  fast   8.148211e+01          0      9  obj_search
# 1609049  1609049  fast  1.797693e+308          0      9  obj_search
# 2396744  2396744  fast  1.797693e+308          0      9  obj_search
# 1801049  1801049  fast  1.797693e+308          0      9  obj_search
#
#                time
# 14819    115.296619
# 203625   111.555013
# 920702    85.750439
# 909570    74.496363
# 56933     59.947260
# ...             ...
# 1637681    5.000290
# 2015413    5.000277
# 1609049    5.000089
# 2396744    5.000060
# 1801049    5.000038
#
# [52929 rows x 7 columns]

# %%
# step = 500000
# for i in range(0, 2500000, step):
plt.figure(figsize=(16,3))
sns.lineplot(x='index', y='time', hue='stage', style='stage', data=create_time)
plt.xlabel('timestamp')
plt.ylabel('time (milis)')
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %% [markdown]
# Relative time (FAST vs CkQST)

# %%
# relative_create = create_time[create_time['stage'] == 'insert']['time'].reset_index() - create_time[create_time['stage'] == 'obj_search']['time'].reset_index()
# relative_create
# plt.figure(figsize=(16,8))
# sns.lineplot(data=relative_create)
# plt.xlabel('timestamp')
# plt.ylabel('time (milis)')

# %% [markdown]
# ## Load Queries

# %%
queries_df = pd.read_json('../../data/exported/places_o200000_q2500000_scaled.json', lines=True);
queries_df = queries_df.iloc[200000:, :].reset_index(drop=True).drop(columns=['id']).reset_index()

queries_df.tail()
# Out:
#            index           x           y  \
# 2499995  2499995  409.894898  103.097463
# 2499996  2499996  402.284307  107.998284
# 2499997  2499997  406.953882  110.040834
# 2499998  2499998  412.621720  107.253521
# 2499999  2499999  412.835319  107.262331
#
#                                              keywords  scaled
# 2499995                         [telephone, cellular]    True
# 2499996                                  [contractor]    True
# 2499997                                      [church]    True
# 2499998          [lounge, drinking, eating, cocktail]    True
# 2499999  [coping, plastering, tiling, pool, swimming]    True

# %% [markdown]
# ### Properties of miserable queries

# %%
queries_df.shape
# Out:
# (2500000, 5)

# %%
details = queries_df.join(miserable_queries.set_index('index'), on='index').dropna().sort_values('time', ascending=False)
# details = details[details['name'] == 'fast']
inf_val = details['ar'].max()
details['ar'] = details['ar'].apply(lambda x: np.inf if x >= inf_val else x)
all = details.drop(columns=['x', 'y']).rename(columns={'time': 'insertion time (milis)'})

# %%
obj_search = all[all['stage'] == 'obj_search']
insert = all[all['stage'] == 'insert']

# insert#.join(ckqsts, rsuffix='_')
insert.head(25)
# all.head(25)
# Out:
#            index                                           keywords  scaled  \
# 2372975  2372975                                          [poultry]    True
# 1183280  1183280                 [automobile, frame, straightening]    True
# 909698    909698                                            [house]    True
# 2177215  2177215                     [insulation, heat, contractor]    True
# 2407499  2407499                                              [oil]    True
# 2443796  2443796                                       [laboratory]    True
# 2461707  2461707                  [repairing, automobile, radiator]    True
# 2051002  2051002                              [general, contractor]    True
# 2214306  2214306                                        [apartment]    True
# 2048032  2048032  [county, program, administration, social, manp...    True
# 2371644  2371644                           [demolition, contractor]    True
# 2186677  2186677                                           [center]    True
# 2390058  2390058                            [alternative, abortion]    True
# 2465650  2465650                                    [machine, shop]    True
# 2397649  2397649                                       [accountant]    True
# 2403184  2403184                                  [product, health]    True
# 2153642  2153642                           [excavation, contractor]    True
# 2186829  2186829                                         [surveyor]    True
# 2212146  2212146                                           [grocer]    True
# 2469999  2469999                                       [field, oil]    True
# 2224401  2224401                                            [parks]    True
# 2070336  2070336                                            [pizza]    True
# 2357806  2357806                                         [doughnut]    True
# 2285317  2285317                                [hardware, upgrade]    True
# 2404433  2404433                                          [carrier]    True
#
#          name         ar  des_count  level   stage  insertion time (milis)
# 2372975  fast  14.492126        1.0    8.0  insert               47.586304
# 1183280  fast   1.785704        2.0    7.0  insert               34.611990
# 909698   fast   7.759406        3.0    6.0  insert               16.361095
# 2177215  fast   0.413590        3.0    6.0  insert               11.406370
# 2407499  fast  44.338812        1.0    8.0  insert                8.450513
# 2443796  fast   7.185730        1.0    8.0  insert                8.329108
# 2461707  fast   4.924124        1.0    8.0  insert                7.564510
# 2051002  fast   0.411893        1.0    8.0  insert                7.354419
# 2214306  fast   4.204608        1.0    8.0  insert                7.223286
# 2048032  fast   1.914730        1.0    8.0  insert                7.161801
# 2371644  fast   1.127001        3.0    6.0  insert                7.036884
# 2186677  fast  17.227255        1.0    8.0  insert                6.997507
# 2390058  fast   8.132921        1.0    8.0  insert                6.981658
# 2465650  fast   3.083916        4.0    5.0  insert                6.776067
# 2397649  fast   4.159698        1.0    8.0  insert                6.728809
# 2403184  fast   0.397559        4.0    5.0  insert                6.669327
# 2153642  fast   9.032617        1.0    8.0  insert                6.653079
# 2186829  fast   1.974154        2.0    7.0  insert                6.551366
# 2212146  fast   7.927648        3.0    6.0  insert                6.481013
# 2469999  fast   6.918495        1.0    8.0  insert                6.455643
# 2224401  fast   9.986769        2.0    7.0  insert                6.331727
# 2070336  fast   3.168606        1.0    8.0  insert                6.283325
# 2357806  fast   5.771833        1.0    8.0  insert                6.217633
# 2285317  fast   2.905142        2.0    7.0  insert                6.155292
# 2404433  fast  10.963168        1.0    8.0  insert                6.108101

# %%
obj_search.head(25)
# Out:
#            index                             keywords  scaled  name  \
# 14819      14819                [building, apartment]    True  fast
# 203625    203625                [advisory, financial]    True  fast
# 920702    920702                         [department]    True  fast
# 909570    909570             [consulting, management]    True  fast
# 56933      56933                        [pet, supply]    True  fast
# 2108672  2108672                 [physician, surgeon]    True  fast
# 928181    928181                        [merchandise]    True  fast
# 2053659  2053659                [building, apartment]    True  fast
# 2177850  2177850                        [residential]    True  fast
# 2323467  2323467                             [window]    True  fast
# 2131839  2131839                 [currency, exchange]    True  fast
# 2096984  2096984                            [medical]    True  fast
# 2263576  2263576                             [church]    True  fast
# 2190905  2190905                [heating, contractor]    True  fast
# 2239453  2239453                   [dentist, general]    True  fast
# 2409806  2409806                          [apartment]    True  fast
# 1641815  1641815                             [eating]    True  fast
# 2120174  2120174  [mfg, product, industrial, plastic]    True  fast
# 2397748  2397748                 [interior, designer]    True  fast
# 2348537  2348537                    [website, design]    True  fast
# 904884    904884                       [sand, gravel]    True  fast
# 2179273  2179273                          [fraternal]    True  fast
# 2275556  2275556                          [appraiser]    True  fast
# 2482938  2482938                           [cleaners]    True  fast
# 909559    909559             [excavating, contractor]    True  fast
#
#                  ar  des_count  level       stage  insertion time (milis)
# 14819           inf        0.0    9.0  obj_search              115.296619
# 203625    81.391686        0.0    9.0  obj_search              111.555013
# 920702          inf        0.0    9.0  obj_search               85.750439
# 909570          inf        0.0    9.0  obj_search               74.496363
# 56933           inf        0.0    9.0  obj_search               59.947260
# 2108672         inf        0.0    9.0  obj_search               58.813509
# 928181          inf        0.0    9.0  obj_search               57.739686
# 2053659         inf        0.0    9.0  obj_search               57.193368
# 2177850         inf        0.0    9.0  obj_search               56.600886
# 2323467         inf        0.0    9.0  obj_search               56.124618
# 2131839         inf        0.0    9.0  obj_search               55.618711
# 2096984         inf        0.0    9.0  obj_search               55.534342
# 2263576         inf        0.0    9.0  obj_search               55.477629
# 2190905         inf        0.0    9.0  obj_search               55.070329
# 2239453         inf        0.0    9.0  obj_search               54.197638
# 2409806         inf        0.0    9.0  obj_search               54.165451
# 1641815         inf        0.0    9.0  obj_search               53.252030
# 2120174         inf        0.0    9.0  obj_search               52.358047
# 2397748         inf        0.0    9.0  obj_search               52.105911
# 2348537         inf        0.0    9.0  obj_search               51.774736
# 904884          inf        0.0    9.0  obj_search               50.936740
# 2179273  256.543485        0.0    9.0  obj_search               50.362088
# 2275556         inf        0.0    9.0  obj_search               50.104203
# 2482938         inf        0.0    9.0  obj_search               49.637220
# 909559          inf        0.0    9.0  obj_search               48.717480

# %% [markdown]
# ## Query size vs Insertion time

# %%
stats = create_time.copy()
stats = queries_df.join(stats.set_index('index'), on='index').dropna()

# %%
stats['n_keywords'] = stats['keywords'].apply(lambda x: min(len(x), 5))

# %% [markdown]
# ### Query index insert

# %%
insert_only = pd.DataFrame(stats[stats['stage'] == 'insert'])
insert_only['ar'] = insert_only['ar'].apply(lambda x: 512 if x > 512 else x)

sns.scatterplot(y='time', x='ar', data=insert_only.loc[:, ['ar', 'time']])
# Out:
# <Axes: xlabel='ar', ylabel='time'>

# %%
sns.scatterplot(y='time', x='n_keywords', data=insert_only.loc[:, ['n_keywords', 'time']])
# Out:
# <Axes: xlabel='n_keywords', ylabel='time'>

# %%
sns.scatterplot(y='time', x='des_count', data=insert_only.loc[:, ['des_count', 'time']])
# Out:
# <Axes: xlabel='des_count', ylabel='time'>

# %%
sns.scatterplot(y='time', x='level', data=insert_only.loc[:, ['level', 'time']])
# Out:
# <Axes: xlabel='level', ylabel='time'>

# %%
out = insert_only.loc[:, ['level', 'time']]

# %%
sns.histplot(out['level'])
# Out:
# <Axes: xlabel='level', ylabel='Count'>

# %%
sns.histplot(out['level'])
plt.ylim(0, 15000)
# Out:
# (0.0, 15000.0)

# %%
hist_out = out.groupby('level').mean().reset_index()
sns.barplot(x='level', y='time', data=hist_out)
plt.ylabel('avg. insert time (query index - fast)')
# Out:
# Text(0, 0.5, 'avg. insert time (query index - fast)')

# %% [markdown]
# ### Obj index search

# %%
search_only = pd.DataFrame(stats[stats['stage'] == 'obj_search'])
search_only['ar'] = search_only['ar'].apply(lambda x: 512 if x > 512 else x)

sns.scatterplot(y='time', x='ar', data=search_only.loc[:, ['ar', 'time']])
# Out:
# <Axes: xlabel='ar', ylabel='time'>

# %%
sns.scatterplot(y='time', x='n_keywords', data=search_only.loc[:, ['n_keywords', 'time']])
# Out:
# <Axes: xlabel='n_keywords', ylabel='time'>

# %%
sns.scatterplot(y='time', x='des_count', data=search_only.loc[:, ['des_count', 'time']])
# Out:
# <Axes: xlabel='des_count', ylabel='time'>

# %%
sns.scatterplot(y='time', x='level', data=search_only.loc[:, ['level', 'time']])
# Out:
# <Axes: xlabel='level', ylabel='time'>
