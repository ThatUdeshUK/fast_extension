# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

import warnings
warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")

font = {'size'   : 12}

matplotlib.rc('font', **font)

# %%
create_time = pd.read_csv("../results_03_01/FAST_KNN_NO_ObjIndex_search_sub_timeline_2500000_100000.csv", names=['obj_search', 'insert']).reset_index()
create_time['name'] = 'fast'
create_time['obj_search'] = create_time['obj_search'] / 1000000
create_time['insert'] = create_time['insert'] / 1000000
create_time = create_time.melt(id_vars=['index', 'name'], var_name='stage', value_name='time')

create_time
# Out:
#            index  name       stage      time
# 0              0  fast  obj_search  9.257749
# 1              1  fast  obj_search  6.433882
# 2              2  fast  obj_search  0.219031
# 3              3  fast  obj_search  0.175755
# 4              4  fast  obj_search  0.407020
# ...          ...   ...         ...       ...
# 4999995  2499995  fast      insert  0.003496
# 4999996  2499996  fast      insert  0.001462
# 4999997  2499997  fast      insert  0.003996
# 4999998  2499998  fast      insert  0.002028
# 4999999  2499999  fast      insert  0.001418
#
# [5000000 rows x 4 columns]

# %% [markdown]
# ## Creation time

# %%
plt.figure(figsize=(16,3))
sns.histplot(x='time', bins=500, hue='stage', multiple='layer', data=create_time)
plt.xlabel('time (milis)')
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# **Miserable queries**
#
# Queries that takes too much time (>100 milis).

# %%
miserable_queries = create_time[create_time['time'] > 50].sort_values('time', ascending=False)
miserable_queries
# Out:
#            index  name       stage        time
# 2294335  2294335  fast  obj_search  199.087662
# 2146534  2146534  fast  obj_search  140.189837
# 2113780  2113780  fast  obj_search  129.927067
# 624299    624299  fast  obj_search  128.135970
# 718693    718693  fast  obj_search  121.412311
# ...          ...   ...         ...         ...
# 872108    872108  fast  obj_search   50.485918
# 2388092  2388092  fast  obj_search   50.384827
# 980051    980051  fast  obj_search   50.342808
# 288319    288319  fast  obj_search   50.214662
# 2286071  2286071  fast  obj_search   50.104498
#
# [197 rows x 4 columns]

# %%
# step = 500000
# for i in range(0, 2500000, step):
plt.figure(figsize=(16,3))
sns.lineplot(x='index', y='time', hue='stage', style='stage', data=create_time)
plt.xlabel('timestamp')
plt.ylabel('time (milis)')
# Out:
# Text(0, 0.5, 'time (milis)')

# %% [markdown]
# Relative time (FAST vs CkQST)

# %%
# relative_create = create_time[create_time['stage'] == 'insert']['time'].reset_index() - create_time[create_time['stage'] == 'obj_search']['time'].reset_index()
# relative_create
# plt.figure(figsize=(16,8))
# sns.lineplot(data=relative_create)
# plt.xlabel('timestamp')
# plt.ylabel('time (milis)')

# %% [markdown]
# ## Load Queries

# %%
queries_df = pd.read_csv('../data/Places_Queries_2500000.csv');

queries_df.tail()
# Out:
#               id           x           y             keywords  k         ar  \
# 2499995  2499995  260.643938  110.297883           contractor  5   0.195442
# 2499996  2499996  278.661373  197.628919                 used  5   3.854567
# 2499997  2499997  260.217315   69.398765  carpet|cleaners|rug  5   4.791082
# 2499998  2499998  167.413845  140.794951             regional  5  53.612263
# 2499999  2499999  256.967070   86.626912               church  5   0.874051
#
#          current_level       st       et
# 2499995              9  2499995  2800001
# 2499996              9  2499996  2800001
# 2499997              9  2499997  2800001
# 2499998              9  2499998  2800001
# 2499999              9  2499999  2800001

# %% [markdown]
# ### Properties of miserable queries

# %%
queries_df.shape
# Out:
# (2500000, 9)

# %%
details = queries_df.join(miserable_queries.set_index('index'), on='id').dropna().sort_values('time', ascending=False)
# details = details[details['name'] == 'fast']
details['ar'] = details['ar'].apply(lambda x: np.inf if x > 512 else x)
all = details.drop(columns=['current_level', 'id', 'k', 'st', 'et']).rename(columns={'time': 'insertion time (milis)'})

# %%
obj_search = all[all['stage'] == 'obj_search']
insert = all[all['stage'] == 'insert']

insert#.join(ckqsts, rsuffix='_')
obj_search.head(25)
# Out:
#                   x           y  \
# 2294335  136.849719  178.148712
# 2146534  228.444134  164.866156
# 2113780  246.894490  201.938389
# 624299    22.047688   28.542137
# 718693   137.446783  185.204339
# 159794   136.793966  188.615945
# 2346308  241.147865  222.392531
# 1866329  241.399982  138.923338
# 639138   258.417080   92.889464
# 2364369  248.848688  132.783435
# 2292551  258.083040   87.599164
# 2096478  245.291766  111.350802
# 2155323  245.213564  111.197889
# 150075   152.161214  134.638136
# 1781326  250.522683  150.648176
# 1845591  134.927347  185.247084
# 2100059  241.974496  221.088191
# 2189821  188.630426  203.104518
# 2221824  244.604749  138.361103
# 2331095  286.911735  220.080628
# 2455446  135.502974  210.038788
# 454302   135.446178  183.156261
# 2480965  257.611607  130.296338
# 2168929  284.904859  214.711285
# 2479062  260.606281  109.596351
#
#                                                   keywords          ar  name  \
# 2294335                                business|mfg|repair         inf  fast
# 2146534                   contractor|trenching|underground   40.664331  fast
# 2113780                    aircraft|equipment|parts|supply  112.695067  fast
# 624299                       contractor|family|general|new         inf  fast
# 718693                      local|storage|trucking|without   40.984215  fast
# 159794                                              church    1.985118  fast
# 2346308                             dealer|religious|store         inf  fast
# 1866329                            contractor|general|road         inf  fast
# 639138           contractor|equipment|installation|station         inf  fast
# 2364369                             organization|religious   14.717663  fast
# 2292551                             industrial|merchandise  133.157824  fast
# 2096478                 automobile|automotive|machine|shop         inf  fast
# 2155323                 contractor|general|property|rental         inf  fast
# 150075                     gasoline|general|repair|station         inf  fast
# 1781326           cabinet|carpentry|contractor|kitchen|mfg         inf  fast
# 1845591      equipment|hearing|impaired|merchandise|supply  144.815152  fast
# 2100059        comm|consultant|decorator|design|furnishing         inf  fast
# 2189821                            contractor|floor|laying    2.147126  fast
# 2221824        cabinet|contractor|custom|specializing|work         inf  fast
# 2331095                                             church    0.201266  fast
# 2455446  air|conditioning|contractor|heating|refrigeration         inf  fast
# 454302       agency|airline|arrangement|operator|passenger         inf  fast
# 2480965                       automobile|general|repairing   11.348119  fast
# 2168929                 construct|contractor|general|house         inf  fast
# 2479062                               cash|register|supply   45.345760  fast
#
#               stage  insertion time (milis)
# 2294335  obj_search              199.087662
# 2146534  obj_search              140.189837
# 2113780  obj_search              129.927067
# 624299   obj_search              128.135970
# 718693   obj_search              121.412311
# 159794   obj_search              116.109171
# 2346308  obj_search              111.902076
# 1866329  obj_search              108.393837
# 639138   obj_search              100.203108
# 2364369  obj_search               97.756249
# 2292551  obj_search               97.581211
# 2096478  obj_search               94.939544
# 2155323  obj_search               93.124376
# 150075   obj_search               89.463635
# 1781326  obj_search               88.978997
# 1845591  obj_search               88.783655
# 2100059  obj_search               85.653514
# 2189821  obj_search               85.566565
# 2221824  obj_search               84.319175
# 2331095  obj_search               83.593368
# 2455446  obj_search               82.617446
# 454302   obj_search               82.089914
# 2480965  obj_search               79.288403
# 2168929  obj_search               78.597517
# 2479062  obj_search               78.279786
