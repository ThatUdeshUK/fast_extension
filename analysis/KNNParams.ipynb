# %% [markdown]
# # KNN Descending params

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data

# %%
res_deg = pd.read_csv("../results_remote/fast_knn_params_deg.csv")
res_deg.head()
# Out:
#   name  creation_time   search_time  create_mem  search_mem  num_queries  \
# 0  inc     1266684693  974409165145           0           0      1000000
# 1  inc      933094154  621851967143           0           0      1000000
# 2  inc     1918354136  510968553811           0           0      1000000
# 3  inc      868397551  458921935186           0           0      1000000
# 4  inc      875403599  494545334622           0           0      1000000
#
#    num_objects  k  knn_deg_ratio  knn_ar_thresh
# 0      1000000  5              0           25.0
# 1      1000000  5             10           25.0
# 2      1000000  5             25           25.0
# 3      1000000  5             50           25.0
# 4      1000000  5             75           25.0

# %%
res_ar = pd.read_csv("../results_remote/fast_knn_params.csv")

# %% [markdown]
# ## Plot

# %%
df = pd.DataFrame(res_deg) 
df['search_time'] = df['search_time'].apply(lambda x: x / 1000000)

sns.lineplot(x='knn_deg_ratio', y='search_time', data=df)
# Out:
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df = pd.DataFrame(res_ar)
df['search_time'] = df['search_time'].apply(lambda x: x / 1000000)

sns.lineplot(x='knn_ar_thresh', y='search_time', data=df)
# Out:
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df = pd.DataFrame(res_ar)
df = df[df['knn_ar_thresh'] <=25]
df['search_time'] = df['search_time'].apply(lambda x: x / 100000)

sns.lineplot(x='knn_ar_thresh', y='search_time', data=df)
# Out:
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/udeshuk/Library/miniconda3/envs/fast/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
